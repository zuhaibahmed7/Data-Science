# %% [markdown]
# <a href="https://colab.research.google.com/github/zuhaibahmed7/Data-Science/blob/main/Build_%26_Design_Multi_Agent_System_Manara.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Install the package Google's ADK (Agent development Kit)
# !pip install google-adk

# %%
#Install the package genai of google
# !pip install google-genai

# %%
import os
from google.colab import userdata

# 1. Set the API key as an environment variable
os.environ["GOOGLE_API_KEY"] = userdata.get('GOOGLE_API_KEY')

# 2. Tell ADK to use the Google AI Studio API instead of Vertex AI
os.environ["GOOGLE_GENAI_USE_VERTEXAI"] = "False"

print("Environment variables set. Now you can run the ADK server.")
# Out:
# Environment variables set. Now you can run the ADK server.

# %%
#Create an AI Agent using ADK
# !adk create my_agent
# Out:
# Choose a model for the root agent:
# 1. gemini-2.5-flash
# 2. Other models (fill later)
# Choose model (1, 2): 2
#
# Please see below guide to configure other models:
# https://google.github.io/adk-docs/agents/models
#
#
# Agent created in /content/my_agent:
# - .env
# - __init__.py
# - agent.py

# %%
#Deploy our AI Agent to ADK Web
get_ipython().system_raw('adk web --port 8000 &')

# %%
from google.colab import output

# This will embed the web interface directly into the output of this cell
output.serve_kernel_port_as_iframe(8000)
